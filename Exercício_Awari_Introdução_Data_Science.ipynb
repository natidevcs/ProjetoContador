# %% [markdown]
# <a href="https://colab.research.google.com/github/natidevcs/ProjetoContador/blob/main/Exerc%C3%ADcio_Awari_Introdu%C3%A7%C3%A3o_Data_Science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Estatística Descritiva**
#
#
# ---

# %% [markdown]
# ### A estatística descritiva é a etapa inicial da análise de dados e tem por objetivo descrever os dados observados. Na sua função de descrição dos dados, esta tem as seguintes atribuições: a obtenção, organização, redução e representação dos dados estatísticos de forma a auxiliar a descrição do fenômeno observado.

# %% [markdown]
# # Estatística descritiva em Python

# %% [markdown]
# # Nessa aula você irá rever:
#
# ##  Fundamentos python:
#
#     *   Números e Strings
#     *   Variáveis
#     *   Print
#     *   Listas

# %%
10 / 2

# %%
10 * 10

# %%
10 / 2

# %%
10 * 10 / 10

# %%
(2 *3) / 4

# %% [markdown]
# ## AGORA VOCÊ:
#
# # - Calcule sua idade!

# %%
a = 2022
b = 1993
idade = a - b
print(idade)
# Out:
# 29

# %% [markdown]
# # 2) Strings

# %%
'Sorvete'

# %%
'Caramelo'

# %% [markdown]
# # Soma de Strings --> Concatenação

# %%
'Sorvete' + ' Caramelo'

# %% [markdown]
# # AGORA VOCÊ:
# ## - Concatene seu nome!

# %%
a = 'natalia'
b = 'pereira'
c = 'natalia ' + 'pereira'
print(c)
# Out:
# natalia pereira

# %% [markdown]
# # 3) Variáveis
#
# Como Shakespeare escreveu: Uma rosa com qualquer outro nome teria o mesmo cheiro doce. Uma variável em Python simplesmente contém um valor - você pode chamá-la de qualquer nome que quiser.

# %%
melhor_linguagem = 'python'
melhor_linguagem

# %%
numero = 1

# %% [markdown]
# # AGORA VOCÊ:
# ## Crie uma variável com seu nome!

# %%
Natalia_Pereira = 'Natalia Pereira'

# %% [markdown]
# # 4) Print
# Nos notebooks Databricks / Jupyter, ele imprimirá automaticamente a última linha da célula que avalia.
#
# No entanto, podemos forçá-lo a imprimir outros componentes usando uma instrução de impressão.

# %%
print("Olá, qual a melhor linguagem?")
print(melhor_linguagem)

# %% [markdown]
# Você também pode ser mais explícito sobre o que está imprimindo. Você pode adicionar sua variável dentro do seu extrato de impressão.

# %%
print(f"{melhor_linguagem} é a melhor linguagem.")

# %% [markdown]
# # AGORA VOCÊ:
# ## "Meu nome é" e imprima seu nome da variável que criou

# %%
print("Meu nome é ")
print(Natalia_Pereira)
# Out:
# Meu nome é
# Natalia Pereira

# %% [markdown]
# # 5) Listas
#   Uma lista (list) em Python é uma sequência ou coleção ordenada de valores. Os valores que formam uma lista são chamados de forma singular de elementos ou itens. Listas são similares a strings, que são uma sequência de caracteres, no entanto, diferentemente de strings, os itens de uma lista podem ser de tipos diferentes.

# %%
lista_de_compras = ["Ovo", "Leite" , "Chocolate", "Danone"]

# %%
lista_de_compras

# %%
lista_de_compras.append("Frango")

# %%
lista_de_compras

# %% [markdown]
# Vamos pegar o primeiro elemento da nossa lista de café
#
# OBS: tudo em Python é indexado em 0, então o primeiro elemento está na posição 0.

# %%
lista_de_compras[0]

# %% [markdown]
# Vamos pegar o último item da nossa lista de compras.

# %%
lista_de_compras[-1]

# %% [markdown]
# E se eu quiser o segundo item em diante?

# %%
lista_de_compras [1:]

# %% [markdown]
# # AGORA VOCÊ:
# ## Mostre o 2o nome da lista de compras!

# %%
lista_de_compras = ["Ovo", "Leite" , "Chocolate", "Danone"]
lista_de_compras.append("Frango")
lista_de_compras

lista_de_compras[1]
# Out:
# 'Leite'

# %% [markdown]
# # EXCELENTE! VAMOS AVANÇAR MAIS!

# %% [markdown]
# > Vamos agora fazer estatística
# >> Usaremos o dataset do Titanic
# >> Aprenderemos o conceito de Dataframe
# >> Faremos as análises em scripts Python

# %% [markdown]
# # Pandas Dataframe
#
# Pandas DataFrame é uma estrutura de dados bidimensional com os dados alinhados de forma tabular em linhas e colunas, mutável em tamanho e potencialmente heterogênea, semelhantemente a uma pasta de trabalho do MS-EXCEL.
#
# ![dataframe_image.png](data:image/png;base64,...)

# %% [markdown]
# # Funções estatísticas no Pandas
#
#
# ![Screen Shot 2021-10-07 at 18.36.32.png](data:image/png;base64,...)

# %% [markdown]
# # Estatística Descritiva - Revisão

# %% [markdown]
# Estatística Descritiva é a parte da Estatística que visa descrever e sumarizar um conjunto de dados. Para isso, são usadas uma série de medidas, como a famosa média.

# %% [markdown]
# # Medidas de Tendência Central

# %% [markdown]
# As medidas de tendência central definem valores significativos, representativos e adequados para um conjunto de dados, dependendo do que se deseja analisar. São elas a média, mediana, quantis e a moda

# %% [markdown]
# # Média

# %% [markdown]
# A média é uma medida de tendência central que indica o valor onde estão concentrados os dados de um conjunto de valores, representando um valor significativo para o mesmo.
#
# No caso dos Dataframes do Pandas, a média é calculada através da função mean() dos Dataframes, que também está presente nas Series do Pandas. Vamos criar uma Series do Pandas e calcular sua média, e também vamos calcular a idade média dos passageiros do Titanic:

# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
arquivo = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(arquivo)
df

# %% [markdown]
# # Nome das colunas ou váriáveis do dataset

# %%
df.columns

# %% [markdown]
# ## Média de idade dos passageiros

# %%
df['Age'].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-48333c3e1f6c> in <module>
# ----> 1 df['Age'].mean()
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Moda

# %% [markdown]
# A moda é simples. Nada mais é que o valor que mais se repete dentro de um conjunto. No Pandas, a moda é calculada através da função mode(). Vejamos os exemplos:

# %%
df['Age'].mode()

# %% [markdown]
# # AGORA VOCÊ!
# ### Calcule o valor médio da Tarifa (Fare)

# %%
df['Fare'].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-c0f06a806f48> in <module>
# ----> 1 df['Fare'].mean()
#
# NameError: name 'df' is not defined

# %% [markdown]
# # AGORA VOCÊ!
# ### Qual é a tarifa com mais ocorrências? (Moda)

# %%
df['Fare'].mode()

# %% [markdown]
# # MUITO BEM!!!
#
# ### Você começou a analisar dados em Python
#
# # PARABÉNS
